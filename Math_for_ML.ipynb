# %% [markdown]
# <a href="https://colab.research.google.com/github/lukaszplust/Machine-Learning/blob/main/Math_for_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 40, 1000) # start, finish, n points
#np.linespace tworzy tablicę jako ciąg 1000 liczb od 0 do 40, gdzie różnica pomiędzy kolejnymi wartościami jest taka sama

# %% [markdown]
# Example:
#
# Sheriff has 180 km/h -->/60 ==> 3km/min
#
# Robber has 150 km/h and 5-min head start -->/60 ==> 2.5km/min

# %%
d_s = 3 * (t-5)#sheriif
d_r = 2.5 * t #robber

# %%
fig, ax = plt.subplots()
plt.title('A Bank Robber Caught')#title
plt.xlabel('time (in minutes)')# name x label
plt.ylabel('distance (in km)')# name y label
ax.set_xlim([0, 40])# limit x axis
ax.set_ylim([0, 100])# limit y axis
ax.plot(t, d_r, c='green')# color of robber plot
ax.plot(t, d_s, c='brown')# color of sheriff plot
plt.axvline(x=30, color='purple', linestyle='--')# the line x where the caught each other
_ = plt.axhline(y=75, color='purple', linestyle='--')# the line y where the caught each other

# %% [markdown]
# NEXT ONE:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Some exaples:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Scalars
# Rank 0 tensor

# %%
x = 25
type(x)
# Out:
# int

# %%
y=3
type(y)
# Out:
# int

# %%
sum = x + y
type(sum)
# Out:
# int

# %%
x_float = 12.0
float_sum = x_float + y
type(float_sum)
# Out:
# float

# %% [markdown]
# ### Scalars in PyTorch
#
# * PyTorch and TensorFlow are the two most popular *automatic differentiation* libraries (a focus of the [*Calculus I*](https://github.com/jonkrohn/ML-foundations/blob/master/notebooks/3-calculus-i.ipynb) and [*Calculus II*](https://github.com/jonkrohn/ML-foundations/blob/master/notebooks/4-calculus-ii.ipynb) subjects in the *ML Foundations* series) in Python, itself the most popular programming language in ML
# * PyTorch tensors are designed to be pythonic, i.e., to feel and behave like NumPy arrays
# * The advantage of PyTorch tensors relative to NumPy arrays is that they easily be used for operations on GPU (see [here](https://pytorch.org/tutorials/beginner/examples_tensor/two_layer_net_tensor.html) for example)
# * Documentation on PyTorch tensors, including available data types, is [here](https://pytorch.org/docs/stable/tensors.html)

# %%
import torch

# %%
x_pt = torch.tensor(25)# type specification optional, e.g.: dtype=torch.float16
x_pt
# Out:
# tensor(25)

# %%
x_pt.shape #output would be clear due to this that scalars have NO DIMENSION !!!
# Out:
# torch.Size([])

# %% [markdown]
# ### Scalars in TensorFlow (version 2.0 or later)
#
# Tensors created with a wrapper, all of which [you can read about here](https://www.tensorflow.org/guide/tensor):
#
# * `tf.Variable`
# * `tf.constant`
# * `tf.placeholder`
# * `tf.SparseTensor`
#
# Most widely-used is `tf.Variable`, which we'll use here.
#
# As with TF tensors, in PyTorch we can similarly perform operations, and we can easily convert to and from NumPy arrays
#
# Also, a full list of tensor data types is available [here](https://www.tensorflow.org/api_docs/python/tf/dtypes/DType).

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(25)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=25>

# %%
x_tf.shape# would be clear becasue scalar has no dimension
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(3)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=3>

# %%
x_tf + y_tf
print(x_tf + y_tf)
tf_sum = tf.add(x_tf, y_tf)# same as "x_tf + y_tf"
tf_sum
# Out:
# tf.Tensor(28, shape=(), dtype=int32)
# <tf.Tensor: shape=(), dtype=int32, numpy=28>

# %%
print(tf_sum.numpy())
type(tf_sum.numpy())
# Out:
# 28
# numpy.int32

# %% [markdown]
# ### Vectors (Rank 1 Tensors) in NumPy

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = np.array([25,2 ,5])
x
# Out:
# array([25,  2,  5])

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3,)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0]
# Out:
# 25

# %%
type(x[1])
# Out:
# numpy.int64

# %% [markdown]
# ### Vector Transposition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Transposing a regular 1-D array has no effect...
x_t = x.T
x_t
# Out:
# array([25,  2,  5])

# %%
x_t.shape
# Out:
# (3,)

# %%
# ...but it does we use nested "matrix-style" brackets:
y = np.array([[25, 2, 5]])
y
# Out:
# array([[25,  2,  5]])

# %%
y.shape
# Out:
# (1, 3)

# %%
# ...but can transpose a matrix with a dimension of length 1, which is mathematically equivalent:
y_t = y.T
y_t
# Out:
# array([[25],
#        [ 2],
#        [ 5]])

# %%
y_t.shape
# Out:
# (3, 1)

# %%
y_t.T.shape
# Out:
# (1, 3)

# %% [markdown]
# ### Zero Vectors
#
# Have no effect if added to another vector

# %%
z = np.zeros(3)
z
# Out:
# array([0., 0., 0.])

# %% [markdown]
# ### Vectors in PyTorch and TensorFlow

# %%
#in pytorch
x_pt = torch.tensor([25, 2, 5])
x_pt
# Out:
# tensor([25,  2,  5])

# %%
#in tensorflow
x_tf = tf.Variable([25, 2, 5])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2,  5], dtype=int32)>

# %% [markdown]
# ### $L^2$ Norm

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2,  5], dtype=int32)>

# %%
import math
print(math.sqrt((25**2 + 2**2 + 5**2)))
#if we can't use math.sqrt we should consider using **(1/2)
(25**2 + 2**2 + 5**2)**(1/2)
# Out:
# 25.573423705088842
# 25.573423705088842

# %% [markdown]
# In the other hand to calculate norm we can use np.linalg.norm()

# %%
np.linalg.norm(x_tf)
# Out:
# 25.573423705088842

# %% [markdown]
# So, if units in this 3-dimensional vector space are meters, then the vector $x$ has a length of 25.6m

# %% [markdown]
# ### $L^1$ Norm

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2,  5], dtype=int32)>

# %%
np.abs(x_tf[0]) + np.abs(x_tf[1]) + np.abs(x_tf[2])
# Out:
# 32

# %% [markdown]
# ### Squared $L^2$ Norm

# %%
(x_tf[0])**2 + (x_tf[1])**2 + (x_tf[2])**2
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=654>

# %%
# we'll cover tensor multiplication more soon but to prove point quickly:
# that will be the same result as before
np.dot(x_tf, x_tf)
# Out:
# 654

# %% [markdown]
# ### Max Norm

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#remember about [] in np.max otherwise it will be TypeError
np.max([np.abs(x_tf[0]),np.abs(x_tf[1]),np.abs(x_tf[2])])
# Out:
# 25

# %% [markdown]
# ### Orthogonal Vectors

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
i = np.array([1,0])
j = np.array([0,1])

# %%
print(i)
print(j)
print(i.T)
# Out:
# [1 0]
# [0 1]
# [1 0]

# %%
# if x.T * y = 0 they are orthogonal
np.dot(i.T,j)
# Out:
# 0

# %% [markdown]
# ### Matrices (Rank 2 Tensors) in NumPy

# %%
# Use array() with nested brackets:
X = np.array([[25, 2], [5, 26], [3, 7]])
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X.shape
# Out:
# (3, 2)

# %%
X.size# total number of elements
# Out:
# 6

# %%
X[:,1] # all row, 1 column
# Out:
# array([ 2, 26,  7])

# %%
X[:,:]# all rows all columns
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X[1,:]# 1 row, all comuns
# Out:
# array([ 5, 26])

# %%
X[0:3, 0:2]# in this situation if we are going to find 3 rd (its 2 if we calculate from 0) row we have to use 3.
#then its going to be rows from 0 to 2 inculded (0,1,2), and columns from 0 to 1 (0,1)
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %% [markdown]
# ### Matrices in PyTorch

# %%
X_pt = torch.tensor([[25, 2], [5, 26], [3, 7]])
X_pt
# Out:
# tensor([[25,  2],
#         [ 5, 26],
#         [ 3,  7]])

# %%
X_pt.shape
# Out:
# torch.Size([3, 2])

# %%
X_pt[1,:] # 1 row, all comuns
# Out:
# tensor([ 5, 26])

# %% [markdown]
# ### Matrices in TensorFlow

# %%
X_tf = tf.Variable([[25, 2], [5, 26], [3, 7]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]], dtype=int32)>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([ 5, 26], dtype=int32)>

# %%
#rank 0 -> scalar
#rank 1 -> vector
#rank 2 -> metrics
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %% [markdown]
# ### Higher-Rank Tensors
#
# As an example, rank 4 tensors are common for images, where each dimension corresponds to:
#
# 1. Number of images in training batch, e.g., 32
# 2. Image height in pixels, e.g., 28 for [MNIST digits](http://yann.lecun.com/exdb/mnist/)
# 3. Image width in pixels, e.g., 28
# 4. Number of color channels, e.g., 3 for full-color images (RGB)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
images_pt = torch.zeros([32, 28, 28, 3])

# %%
images_tf = tf.zeros([32, 28, 28, 3])

# %%
#images_tf 4-diemnsion

# %% [markdown]
# Checking out my own exercise acording to rank

# %%
z = tf.Variable([[1,2,3,4], [2,3,4,5]])

# %%
z
# Out:
# <tf.Variable 'Variable:0' shape=(2, 4) dtype=int32, numpy=
# array([[1, 2, 3, 4],
#        [2, 3, 4, 5]], dtype=int32)>

# %%
tf.rank(z)# thats 2 due to fact that its matrics
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %% [markdown]
# ## Segment 2: Common Tensor Operations

# %% [markdown]
# ### Tensor Transposition

# %%
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X.T
# Out:
# array([[25,  5,  3],
#        [ 2, 26,  7]])

# %%
X_pt.T
# Out:
# tensor([[25,  5,  3],
#         [ 2, 26,  7]])

# %%
# Transpose using tensorflow
tf.transpose(X_tf)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[25,  5,  3],
#        [ 2, 26,  7]], dtype=int32)>

# %% [markdown]
# ### Basic Arithmetical Properties

# %%
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X*2
# Out:
# array([[50,  4],
#        [10, 52],
#        [ 6, 14]])

# %%
X+2
# Out:
# array([[27,  4],
#        [ 7, 28],
#        [ 5,  9]])

# %%
X*2+2
# Out:
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]])

# %%
print(X_pt*2+2) # Python operators are overloaded; could alternatively use torch.mul() or torch.add()
print('--------')
print(torch.add(torch.mul(X_pt, 2), 2))
# Out:
# tensor([[52,  6],
#         [12, 54],
#         [ 8, 16]])
# --------
# tensor([[52,  6],
#         [12, 54],
#         [ 8, 16]])

# %%
print(X_tf*2+2) # Operators likewise overloaded; could equally use tf.multiply() tf.add()
print('--------')
print(tf.add(tf.multiply(X_tf, 2), 2))
# Out:
# tf.Tensor(
# [[52  6]
#  [12 54]
#  [ 8 16]], shape=(3, 2), dtype=int32)
# --------
# tf.Tensor(
# [[52  6]
#  [12 54]
#  [ 8 16]], shape=(3, 2), dtype=int32)

# %% [markdown]
# If two tensors have the same size, operations are often by default applied element-wise. This is **not matrix multiplication**, which we'll cover later, but is rather called the **Hadamard product** or simply the **element-wise product**.
#
# The mathematical notation is $A \odot X$

# %%
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
A = X+2
A
# Out:
# array([[27,  4],
#        [ 7, 28],
#        [ 5,  9]])

# %%
A + X
# Out:
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]])

# %%
A * X
# Out:
# array([[675,   8],
#        [ 35, 728],
#        [ 15,  63]])

# %% [markdown]
# ### Tensor Reduction

# %% [markdown]
# Calculating the sum across all elements of a tensor is a common operation. For example:
#
# * For vector ***x*** of length *n*, we calculate $\sum_{i=1}^{n} x_i$
# * For matrix ***X*** with *m* by *n* dimensions, we calculate $\sum_{i=1}^{m} \sum_{j=1}^{n} X_{i,j}$

# %%
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X.sum() # the sum of tensor
# Out:
# 68

# %%
#in pytorch
torch.sum(X_pt)
# Out:
# tensor(68)

# %%
tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=68>

# %%
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
#summing along specific axis alone
X.sum(axis=0)# summing all columns
# Out:
# array([33, 35])

# %%
X.sum(axis=1)# summing all rows
# Out:
# array([27, 31, 10])

# %%
#in pytorch
torch.sum(X_pt,0) # sum all calumns
# Out:
# tensor([33, 35])

# %%
#in tensorflow
tf.reduce_sum(X_tf,1) # sum all rows
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([27, 31, 10], dtype=int32)>

# %% [markdown]
# Many other operations can be applied with reduction along all or a selection of axes, e.g.:
#
# * maximum
# * minimum
# * mean
# * product
#
# They're fairly straightforward and used less often than summation, so you're welcome to look them up in library docs if you ever need them.

# %% [markdown]
# ### The Dot Product

# %% [markdown]
# If we have two vectors (say, ***x*** and ***y***) with the same length *n*, we can calculate the dot product between them. This is annotated several different ways, including the following:
#
# * $x \cdot y$
# * $x^Ty$
# * $\langle x,y \rangle$
#
# Regardless which notation you use (I prefer the first), the calculation is the same; we calculate products in an element-wise fashion and then sum reductively across the products to a scalar value. That is, $x \cdot y = \sum_{i=1}^{n} x_i y_i$
#
# The dot product is ubiquitous (wszechobecny) in deep learning: It is performed at every artificial neuron in a deep neural network, which may be made up of millions (or orders of magnitude more) of these neurons.

# %%
x
# Out:
# array([25,  2,  5])

# %%
y = np.array([0,1,2])
y
# Out:
# array([0, 1, 2])

# %%
25*0 + 2*1 + 2*5
# Out:
# 12

# %%
np.dot(x,y)
# Out:
# 12

# %%
x_pt
# Out:
# tensor([25,  2,  5])

# %%
#in pytorch
y_pt = torch.tensor([0,1,2])
y_pt
# Out:
# tensor([0, 1, 2])

# %%
np.dot(x_pt, y_pt)
# Out:
# 12

# %%
torch.dot(torch.tensor([25, 2, 5.]), torch.tensor([0, 1, 2.]))# because of (.) it will be float value
# Out:
# tensor(12.)

# %%
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2,  5], dtype=int32)>

# %%
#in tensorflow
y_tf = tf.Variable([0,1,2])
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([0, 1, 2], dtype=int32)>

# %%
tf.reduce_sum(tf.multiply(x_tf, y_tf))
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=12>

# %% [markdown]
# ### Solving Linear Systems

# %% [markdown]
# In the **Substitution** example, the two equations in the system are:
# $$ y = 3x $$
# $$ -5x + 2y = 2 $$
#
# The second equation can be rearranged to isolate $y$:
# $$ 2y = 2 + 5x $$
# $$ y = \frac{2 + 5x}{2} = 1 + \frac{5x}{2} $$

# %%
 #simulating X values over ssome particular range
 x = np.linspace(-10, 10 ,1000) # start, finish, n-points

# %%
y1 = 3 * x

# %%
y2 = 1 + (5*x)/2

# %%
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('y')
ax.set_xlim([0, 3])
ax.set_ylim([0, 8])
ax.plot(x, y1, c='green')
ax.plot(x, y2, c='brown')
plt.axvline(x=2, color='purple', linestyle='--')
_ = plt.axhline(y=6, color='purple', linestyle='--')
# THE RESULT IS
# x = 2, y = 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In the **Elimination** example, the two equations in the system are:
# $$ 2x - 3y = 15 $$
# $$ 4x + 10y = 14 $$
#
# Both equations can be rearranged to isolate $y$. Starting with the first equation:
# $$ -3y = 15 - 2x $$
# $$ y = \frac{15 - 2x}{-3} = -5 + \frac{2x}{3} $$
#
# Then for the second equation:
# $$ 4x + 10y = 14 $$
# $$ 2x + 5y = 7 $$
# $$ 5y = 7 - 2x $$
# $$ y = \frac{7 - 2x}{5} $$

# %%
y1 = -5 + (2*x)/3

# %%
y2 = (7 - (2*x))/5

# %%
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('y')
ax.set_xlim([0, 10])
ax.set_ylim([-5, 5])
ax.plot(x, y1, c='green')
ax.plot(x, y2, c='brown')
plt.axvline(x=6, color='purple', linestyle='--')
_ = plt.axhline(y=-1, color='purple', linestyle='--')
# THE RESULT IS
# x = 6, y = -1
